# %% [markdown]
# # Building an image model from results obtained by fitting:

# %% [markdown]
# ## M51 test data

# %% [markdown]
# Initially we fit the M51 test image; then, from the fit results we build a model, and finnaly we subtract the model from the original image.

# %%
from astropy.io import fits
image = fits.open("../../test/data/M51.fits")
pixel_data = image[0].data

from ellipse.ellipse import Ellipse
ellipse = Ellipse(pixel_data)
isolist = ellipse.fit_image(sclip=2., nclip=3)
# Out:
# Centering on object....   Done. Found x0 = 257.0, y0 = 258.0
# #
# # Semi-      Isophote         Ellipticity    Position     Grad.   Data  Flag Iter. Stop
# # major        mean                           Angle        rel.                    code
# # axis       intensity                                    error
# #(pixel)                                     (degree)
# #
#   10.00     1089.59 ( 8.44)  0.102 (0.006)  65.93 ( 2.0)  0.191    60     0   20     0
#   11.00     1044.70 ( 7.70)  0.132 (0.005)  72.93 ( 1.1)  0.150    65     0   10     0
#   12.10      983.21 ( 5.88)  0.157 (0.003)  70.03 ( 0.6)  0.122    61     9   10     0
#   13.31      916.06 ( 7.32)  0.157 (0.006)  49.90 ( 1.3)  0.216    70     7   50     2
#   14.64      895.94 ( 6.87)  0.223 (0.004)  55.85 ( 0.7)  0.160    77     4   19     0
#   16.11      868.99 ( 5.41)  0.282 (0.003)  51.85 ( 0.5)  0.152    76    10   12     0
#   17.72      851.25 ( 5.75)  0.282 (0.003)  43.00 ( 0.3)  0.119    79    15   12     0
#   19.49      731.82 ( 4.44)  0.154 (0.002)  32.80 ( 0.3)  0.082    88    25   11     0
#   21.44      689.18 ( 5.18)  0.239 (0.002)  36.47 ( 0.3)  0.112   102    15   10     0
#   23.58      634.82 ( 7.00)  0.285 (0.002)  36.47 ( 0.2)  0.102   111    14   10     0
#   25.94      533.36 ( 5.05)  0.264 (0.001)  40.23 ( 0.2)  0.086   123    16   11     0
#   28.53      556.56 ( 5.04)  0.348 (0.001)  47.71 ( 0.1)  0.072   123    21   21     0
#   31.38      367.35 ( 4.80)  0.116 (0.002)  71.99 ( 0.6)  0.095   161    25   10     0
#   34.52      294.35 ( 3.72)  0.110 (0.002)  71.99 ( 0.5)  0.087   182    23   10     0
#   37.97      283.46 ( 3.59)  0.114 (0.002)  12.67 ( 0.6)  0.121   193    32   15     0
#   41.77      242.09 ( 2.87)  0.114 (0.002)  25.08 ( 0.6)  0.118   219    29   10     0
#   45.95      210.63 ( 2.34)  0.114 (0.002)  25.08 ( 0.6)  0.111   236    37   50     2
#   50.54      208.59 ( 1.66)  0.195 (0.002) 170.04 ( 0.3)  0.096   247    39   10     0
#   55.60      201.83 ( 1.05)  0.249 (0.001) 163.12 ( 0.1)  0.043   259    44   10     0
#   61.16      166.77 ( 1.08)  0.249 (0.001) 163.12 ( 0.1)  0.096   308    25    3     5
#   67.27      168.57 ( 1.01)  0.298 (0.001)  60.51 ( 0.1)  0.074   297    57   15     0
#   74.00      149.81 ( 0.97)  0.298 (0.001)  60.51 ( 0.2)  None    332    57    9     5
#   81.40      152.51 ( 0.75)  0.258 (0.001)  69.92 ( 0.1)  0.094   381    60   50     2
#    0.76     6449.35 (13.03)  0.063 (0.012) 143.75 ( 8.1)  0.169    10     3   21     0
#    0.69     6609.65 (25.92)  0.063 (0.024) 132.73 (12.0)  0.359    13     0   20     0
#    0.63     6656.85 (12.02)  0.053 (0.013) 146.08 (10.4)  0.181    10     3   12     0
#    0.57     6787.21 (23.22)  0.042 (0.025) 138.63 (19.1)  0.360    13     0   28     0
#    0.52     6875.62 (20.50)  0.049 (0.025) 157.23 (16.1)  0.371    13     0   27     0
#    0.00     7607.99

# %% [markdown]
# Now we build a model image.
#
# Note that we use a background estimate taken from the data array itself. This is arbitrary though, just for demo purposes in here.

# %%
import numpy as np
from ellipse.model import build_model

model_image = build_model(pixel_data, isolist, fill=np.mean(pixel_data[0:10,0:10]))
# Out:
# Interpolating....Done
# SMA=119.1
# Done

# %%
print(pixel_data.shape)
print(model_image.shape)
# Out:
# (512, 512)
# (512, 512)

# %% [markdown]
# Display (just the central, modeled region):

# %%
model = model_image[128:384,128:384]
data = pixel_data[128:384,128:384]

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
plt.rcParams['image.origin'] = 'lower'

plt.rcParams['figure.figsize'] = (15.0, 10.0)

fig, (ax1, ax2) = plt.subplots(1, 2)

ax1.imshow(model, cmap=cm.gnuplot, vmin=0, vmax=1000)
ax1.set_title("Model")
ax2.imshow(data, cmap=cm.gnuplot, vmin=0, vmax=1000)
ax2.set_title("Data")

# %% [markdown]
# Finally, subtract model from data:

# %%
residual = data - model

plt.rcParams['figure.figsize'] = (6.0, 6.0)
fig, ax = plt.subplots()

ax.imshow(residual, cmap=cm.gnuplot, vmin=-300, vmax=300)
ax.set_title("Residual")

# %% [markdown]
# ## Elliptical galaxy

# %%
image = fits.open("../../test/data/M105-S001-RGB.fits")
pixel_data = image[0].data[0]

from ellipse.geometry import Geometry
g = Geometry(530., 511, 10., 0.2, 20./180.*3.14)

ellipse = Ellipse(pixel_data, geometry=g)
isolist = ellipse.fit_image()

model_image = build_model(pixel_data, isolist, fill=np.mean(pixel_data[0:100,0:100]))
model = model_image
data = pixel_data
residual = data - model
# Out:
# Centering on object....   Done. Found x0 = 530.0, y0 = 512.0
# #
# # Semi-      Isophote         Ellipticity    Position     Grad.   Data  Flag Iter. Stop
# # major        mean                           Angle        rel.                    code
# # axis       intensity                                    error
# #(pixel)                                     (degree)
# #
#   10.00     1512.34 ( 0.06)  0.066 (0.000)  12.19 ( 0.2)  0.013    61     0   20     0
#   11.00     1505.58 ( 0.06)  0.074 (0.000)  13.00 ( 0.2)  0.015    67     0   10     0
#   12.10     1499.54 ( 0.07)  0.077 (0.001)  12.89 ( 0.2)  0.016    74     0   10     0
#   13.31     1494.16 ( 0.05)  0.082 (0.000)  12.69 ( 0.2)  0.016    81     0   10     0
#   14.64     1489.53 ( 0.05)  0.083 (0.001)  12.11 ( 0.2)  0.019    89     0   10     0
#   16.11     1485.90 ( 0.05)  0.088 (0.001)  10.68 ( 0.2)  0.023    97     0   10     0
#   17.72     1483.12 ( 0.05)  0.097 (0.001)  11.79 ( 0.2)  0.027   106     0   10     0
#   19.49     1480.81 ( 0.04)  0.105 (0.001)  11.44 ( 0.2)  0.038   116     0   10     0
#    3.19     1697.24 ( 0.36)  0.054 (0.001)  82.28 ( 0.8)  0.023    20     0   10     0
#    2.90     1718.63 ( 0.31)  0.060 (0.001)  83.84 ( 0.7)  0.023    18     0   10     0
#    2.63     1738.51 ( 0.49)  0.051 (0.002)  85.08 ( 1.3)  0.030    17     0   10     0
#    2.39     1755.57 ( 0.35)  0.036 (0.002)  79.75 ( 1.5)  0.035    15     0   50     2
#    2.18     1772.65 ( 0.44)  0.031 (0.003)  84.57 ( 2.6)  0.041    14     0   10     0
#    1.98     1788.92 ( 0.69)  0.014 (0.004)  71.73 ( 9.6)  0.069    13     0   34     0
#    1.80     1804.81 ( 0.71)  0.016 (0.005)  70.39 ( 9.5)  0.064    13     0   21     0
#    1.64     1819.38 ( 0.77)  0.020 (0.006)  70.39 ( 8.7)  0.074    13     0   50     2
#    1.49     1832.18 ( 0.76)  0.022 (0.006)  71.58 ( 8.9)  0.088    13     0   11     0
#    1.35     1840.03 ( 0.56)  0.029 (0.008)  71.58 ( 8.3)  0.128    13     0   50     2
#    1.23     1853.54 ( 0.64)  0.043 (0.007)  85.15 ( 4.9)  0.094    13     0   50     2
#    1.12     1862.47 ( 0.66)  0.062 (0.008)  84.25 ( 4.1)  0.115    13     0   10     0
#    1.02     1869.34 ( 0.68)  0.061 (0.010)  84.74 ( 5.0)  0.134    13     0   10     0
#    0.92     1874.21 ( 0.99)  0.042 (0.019)  77.96 (13.8)  0.255    13     0   10     0
#    0.84     1879.25 ( 0.75)  0.071 (0.016)   9.77 ( 7.0)  0.218    13     0   11     0
#    0.76     1885.57 ( 0.92)  0.177 (0.020)   1.26 ( 3.9)  0.313    13     0   10     0
#    0.69     1888.46 ( 0.88)  0.187 (0.025) 179.32 ( 4.5)  0.427    13     0   50     2
#    0.63     1890.97 ( 0.79)  0.187 (0.025) 179.32 ( 4.6)  0.439    13     0   50     2
#    0.57     1893.24 ( 0.72)  0.187 (0.025) 179.32 ( 4.6)  0.439    13     0   50     2
#    0.52     1895.31 ( 0.65)  0.187 (0.025) 179.32 ( 4.6)  0.439    13     0   50     2
#    0.00     1911.80
# Interpolating....Done
# SMA=108.3
# Done

# %%
plt.rcParams['figure.figsize'] = (15.0, 10.0)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
plt.axis([0,1023,0,1023])
ax1.imshow(data, cmap=cm.gnuplot, vmin=1450., vmax=1500.)
ax1.set_title("Data")
ax2.imshow(model, cmap=cm.gnuplot, vmin=1450., vmax=1500.)
ax2.set_title("Model")
ax3.imshow(residual, cmap=cm.gnuplot, vmin=-100, vmax=100)
ax3.set_title("Residual")
ax4.imshow(residual, cmap=cm.gnuplot, vmin=-100, vmax=100)
ax4.set_title("Residual")

iso1 = isolist.get_closest(20.)
iso2 = isolist.get_closest(100.)
iso3 = isolist.get_closest(200.)

x, y, = iso1.sampled_coordinates()
plt.plot(x, y, color='white')
x, y, = iso2.sampled_coordinates()
plt.plot(x, y, color='white')
x, y, = iso3.sampled_coordinates()
plt.plot(x, y, color='white')

# %% [markdown]
# ## Artificial image

# %% [markdown]
# Of course, M51 is not the best object to test this procedure, since the non-elliptical contamination is so significant.
#
# In order to better evaluate the limits of the modeling, we can resort to an artificial image of a "perfectly" elliptical object. That way, at least we can check that the entire procedure: fit -> model -> residual is internally consistent.
#
# We use the 'build_test_data' module in the 'util' package:

# %%
from util.build_test_data import build
from ellipse.geometry import Geometry

pixel_data = build(eps=0.5, pa=np.pi/3., background=10., noise=1.E-12)

g = Geometry(256., 256., 10., 0.5, np.pi/3.)
ellipse = Ellipse(pixel_data, geometry=g)
isolist = ellipse.fit_image()
model_image = build_model(pixel_data, isolist, fill=np.mean(pixel_data[0:10,0:10]))
model = model_image
data = pixel_data
residual = data - model
# Out:
# Centering on object....   Done. Found x0 = 256.0, y0 = 256.0
# #
# # Semi-      Isophote         Ellipticity    Position     Grad.   Data  Flag Iter. Stop
# # major        mean                           Angle        rel.                    code
# # axis       intensity                                    error
# #(pixel)                                     (degree)
# #
#   10.00      953.50 ( 0.37)  0.496 (0.000)  59.99 ( 0.0)  0.004    44     0   20     0
#   11.00      837.95 ( 0.25)  0.497 (0.000)  60.02 ( 0.0)  0.003    48     0   10     0
#   12.10      733.45 ( 0.16)  0.497 (0.000)  60.00 ( 0.0)  0.002    53     0   10     0
#   13.31      641.66 ( 0.11)  0.498 (0.000)  59.99 ( 0.0)  0.002    58     0   10     0
#   14.64      558.99 ( 0.09)  0.498 (0.000)  59.99 ( 0.0)  0.002    64     0   10     0
#   16.11      485.78 ( 0.07)  0.499 (0.000)  60.00 ( 0.0)  0.001    70     0   10     0
#   17.72      420.51 ( 0.04)  0.499 (0.000)  59.99 ( 0.0)  0.001    77     0   10     0
#   19.49      363.03 ( 0.03)  0.499 (0.000)  60.00 ( 0.0)  0.001    85     0   10     0
#   21.44      312.49 ( 0.02)  0.499 (0.000)  60.00 ( 0.0)  0.001    93     0   10     0
#   23.58      268.25 ( 0.01)  0.499 (0.000)  60.00 ( 0.0)  0.000   102     0   10     0
#   25.94      229.59 ( 0.01)  0.499 (0.000)  60.00 ( 0.0)  0.000   112     0   10     0
#   28.53      196.08 ( 0.01)  0.499 (0.000)  60.00 ( 0.0)  0.000   124     0   10     0
#   31.38      167.00 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   136     0   10     0
#   34.52      141.92 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   150     0   10     0
#   37.97      120.38 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   165     0   10     0
#   41.77      101.97 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   181     0   10     0
#   45.95       86.29 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   200     0   10     0
#   50.54       73.00 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   220     0   10     0
#   55.60       61.78 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   242     0   10     0
#   61.16       52.36 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   266     0   10     0
#   67.27       44.49 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   292     0   10     0
#   74.00       37.94 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   322     0   10     0
#   81.40       32.52 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   354     0   10     0
#   89.54       28.06 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   389     0   10     0
#   98.50       24.40 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   428     0   10     0
#  108.35       21.42 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   471     0   10     0
#  119.18       19.01 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   518     0   10     0
#  131.10       17.07 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   569     0   10     0
#  144.21       15.51 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   626     0   10     0
#  158.63       14.27 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   689     0   10     0
#  174.49       13.29 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   757     0   10     0
#  191.94       12.52 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   833     0   10     0
#  211.14       11.92 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.000   916     0   10     0
#  232.25       11.45 ( 0.00)  0.500 (0.000)  60.00 ( 0.0)  0.
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)
plt.axis([0,511,0,511])
ax1.imshow(pixel_data, cmap=cm.gnuplot, vmin=0., vmax=100)
ax1.set_title("Data")
ax2.imshow(model, cmap=cm.gnuplot, vmin=0., vmax=100)
ax2.set_title("Model")
ax3.imshow(residual, cmap=cm.gnuplot, vmin=-3, vmax=3)
ax3.set_title("Residual")
ax4.imshow(residual, cmap=cm.gnuplot, vmin=-3, vmax=3)
ax4.set_title("Residual")

iso1 = isolist.get_closest(20.)
iso2 = isolist.get_closest(100.)
iso3 = isolist.get_closest(200.)

x, y, = iso1.sampled_coordinates()
plt.plot(x, y, color='white')
x, y, = iso2.sampled_coordinates()
plt.plot(x, y, color='white')
x, y, = iso3.sampled_coordinates()
plt.plot(x, y, color='white')

# %% [markdown]
# ### Analysis of central region

# %%
plt.rcParams['figure.figsize'] = (6.0, 6.0)

fig, ax = plt.subplots()

# display center of image
plt.axis([256-25,256+25,256-25,256+25])

ax.imshow(residual, cmap=cm.gnuplot, vmin=-25, vmax=25)
ax.set_title("Residual")

iso1 = isolist.get_closest(5.)
iso2 = isolist.get_closest(7.5)
iso3 = isolist.get_closest(20.)

x, y, = iso1.sampled_coordinates()
plt.plot(x, y, color='white')

x, y, = iso2.sampled_coordinates()
plt.scatter(x, y, color='white')

x, y, = iso3.sampled_coordinates()
plt.plot(x, y, color='white')

# %%
plt.rcParams['figure.figsize'] = (10.0, 2.0)
plt.axis([50.,450.,2100.,2220.])
print(iso1.sma)
plt.scatter((iso1.sample.values[0]+iso1.sample.geometry.pa)/np.pi*180., iso1.sample.values[2], color='red')
plt.ylabel("Intensity")
plt.xlabel("Angle (deg.)")
# Out:
# 5.131581182307066

# %%
plt.axis([50.,450.,1350.,1410.])
print(iso2.sma)
plt.scatter((iso2.sample.values[0]+iso2.sample.geometry.pa)/np.pi*180., iso2.sample.values[2], color='blue')
# Out:
# 7.513148009015777

# %%
iso4 = isolist.get_closest(80.)
plt.axis([50.,450.,28.,36.])
print(iso4.sma)
plt.scatter((iso4.sample.values[0]+iso4.sample.geometry.pa)/np.pi*180., iso4.sample.values[2], color='green')
# Out:
# 81.4027493868399

# %%
plt.rcParams['figure.figsize'] = (10.0, 5.0)
plt.figure(1)

axis = [0., 5., -10., 10.]

plt.subplot(221)
plt.axis(axis)
plt.errorbar(isolist.sma, isolist.a3, yerr=isolist.a3_err, fmt='o', markersize=4)
plt.title('A3')

plt.subplot(222)
plt.axis(axis)
plt.errorbar(isolist.sma, isolist.b3, yerr=isolist.b3_err, fmt='o', markersize=4)
plt.title('B3')

plt.subplot(223)
plt.axis(axis)
plt.errorbar(isolist.sma, isolist.a4, yerr=isolist.a4_err, fmt='o', markersize=4)
plt.title('A4')

plt.subplot(224)
plt.axis(axis)
plt.errorbar(isolist.sma, isolist.b4, fmt='o', yerr=isolist.b4_err, markersize=4)
plt.title('B4')

plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.35, wspace=0.35)
